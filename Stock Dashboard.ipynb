# %% [markdown]
# # Stock Dashboard

# %% [markdown]
# Input: Stock Name

# %%
stock_name = '2S'

# %% [markdown]
# load data (data from running Financial Statement Web Scraping.py)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bokeh

# %%
finance_data = pd.read_csv(r'C:\\Users\YIT\Python Stock Analysis\finance info.csv')
print(finance_data.columns)
print(finance_data['Statistics as of'].unique())
# Out:
# Index(['Unnamed: 0', 'Statistics as of', '30/12/2016', '29/12/2017',
#        '28/12/2018', '30/12/2019', '30/04/2020', 'Symbol', 'Name',
#        'Stock Sector', 'Industry Name', 'Market Cap (m)', 'Dividend Yield (%)',
#        'Last (Close)', 'Unnamed: 7'],
#       dtype='object')
# ['Assets' 'Liabilities' 'Equity' 'Paid-up Capital' 'Revenue' 'Net Profit'
#  'EPS (Baht)' 'ROA(%)' 'ROE(%)' 'Net Profit Margin(%)' 'Statistics as of'
#  'Last Price(Baht)' 'Market Cap.' 'F/S Period (As of date)' 'P/E' 'P/BV'
#  'Book Value per share (Baht)' 'Dvd. Yield(%)' 'P/NAV' 'NAV']

# %%
latest_year = '27/12/2019'
finance_data[latest_year] = pd.to_numeric(finance_data[latest_year], errors='coerce')

# %% [markdown]
# P/E ratio grouped by industry name

# %%
finance_data.loc[(finance_data['Statistics as of']=='P/E') & (finance_data['Industry Name']==finance_data.loc[finance_data['Symbol'] == stock_name,'Industry Name' ][1]),:].groupby('Industry Name').agg({latest_year:'mean'})
# Out:
#                27/12/2019
# Industry Name
# Steel           50.820909

# %% [markdown]
# P/E ratio grouped by stock sector

# %%
finance_data.loc[(finance_data['Statistics as of']=='P/E') & (finance_data['Stock Sector']==finance_data.loc[finance_data['Symbol'] == stock_name,'Stock Sector'][1]),:].groupby('Stock Sector').agg({latest_year:'mean'})
# Out:
#                  27/12/2019
# Stock Sector
# Basic Materials   25.708077

# %%
finance_data
# Out:
#        Unnamed: 0             Statistics as of  30/12/2016  29/12/2017  \
# 0               0                       Assets     1753.84     1929.30
# 1               1                  Liabilities      704.23      649.00
# 2               2                       Equity     1052.94     1281.84
# 3               3              Paid-up Capital      300.00      400.00
# 4               4                      Revenue     3946.83     4539.01
# 5               5                   Net Profit      343.07      284.71
# 6               6                   EPS (Baht)        1.14        0.71
# 7               7                       ROA(%)       29.69       20.07
# 8               8                       ROE(%)       37.78       24.39
# 9               9         Net Profit Margin(%)        8.69        6.27
# 10             10             Statistics as of  30/12/2016  29/12/2017
# 11             11             Last Price(Baht)        6.85        5.00
# 12             12                  Market Cap.     2055.00     2000.00
# 13             13      F/S Period (As of date)  30/09/2016  30/09/2017
# 14             14                          P/E        7.53        6.83
# 15             15                         P/BV        2.11        1.65
# 16             16  Book Value per share (Baht)        3.25        3.04
# 17             17                Dvd. Yield(%)        1.46        2.70
# 18             18                       Assets     8495.71     8549.02
# 19             19                  Liabilities     5204.09     5037.65
# 20             20                       Equity     3291.62     3511.37
# 21             21              Paid-up Capital      399.44      399.44
# 22             22                      Revenue     7032.50     7879.44
# 23             23                   Net Profit      121.25      443.44
# 24             24                   EPS (Baht)        0.30        1.11
# 25             25                       ROA(%)        2.58        6.27
# 26             26                       ROE(%)        3.76       13.04
# 27             27         Net Profit Margin(%)        1.72        5.63
# 28             28             Statistics as of  30/12/2016  29/12/2017
# 29             29             Last Price(Baht)       11.40       12.00
# ...           ...                          ...         ...         ...
# 12714       12714                   EPS (Baht)         NaN         NaN
# 12715       12715                       ROA(%)         NaN         NaN
# 12716       12716                       ROE(%)         NaN         NaN
# 12717       12717         Net Profit Margin(%)         NaN         NaN
# 12718       12718             Statistics as of         NaN         NaN
# 12719       12719             Last Price(Baht)         NaN         NaN
# 12720       12720                  Market Cap.         NaN         NaN
# 12721       12721      F/S Period (As of date)         NaN         NaN
# 12722       12722                          P/E         NaN         NaN
# 12723       12723                         P/BV         NaN         NaN
# 12724       12724  Book Value per share (Baht)         NaN         NaN
# 12725       12725                Dvd. Yield(%)         NaN         NaN
# 12726       12726                       Assets         NaN     1281.98
# 12727       12727                  Liabilities         NaN      499.73
# 12728       12728                       Equity         NaN      782.25
# 12729       12729              Paid-up Capital         NaN      260.00
# 12730       12730                      Revenue         NaN      909.95
# 12731       12731                   Net Profit         NaN      131.68
# 12732       12732                   EPS (Baht)         NaN        0.28
# 12733       12733                       ROA(%)         NaN       17.76
# 12734       12734                       ROE(%)         NaN       23.99
# 12735       12735         Net Profit Margin(%)         NaN       14.47
# 12736       12736             Statistics as of         NaN  29/12/2017
# 12737       12737             Last Price(Baht)         NaN        4.96
# 12738       12738                  Market Cap.         NaN     2579.20
# 12739       12739      F/S Period (As of date)         NaN  30/09/2017
# 12740       12740                          P/E         NaN       17.31
# 12741       12741                         P/BV         NaN        3.35
# 12742       12742  Book Value per share (Baht)         NaN        1.48
# 12743       12743                Dvd. Yield(%)         NaN         NaN
#
#        28/12/2018  30/12/2019  30/04/2020 Symbol                 Name  \
# 0         1857.46     1766.51         NaN     2S         2S Metal PCL
# 1          543.27      388.84         NaN     2S         2S Metal PCL
# 2         1315.88     1379.55         NaN     2S         2S Metal PCL
# 3          450.00      450.00         NaN     2S         2S Metal PCL
# 4         5462.98     5413.94         NaN     2S         2S Metal PCL
# 5          105.55      133.38         NaN     2S         2S Metal PCL
# 6            0.23        0.30         NaN     2S         2S Metal PCL
# 7            7.67        9.38         NaN     2S         2S Metal PCL
# 8            8.13        9.90         NaN     2S         2S Metal PCL
# 9            1.93        2.46         NaN     2S         2S Metal PCL
# 10     28/12/2018  30/12/2019  30/04/2020     2S         2S Metal PCL
# 11           2.30        2.00        1.80     2S         2S Metal PCL
# 12        1035.00      900.00      810.00     2S         2S Metal PCL
# 13     30/09/2018  30/09/2019  31/12/2019     2S         2S Metal PCL
# 14           5.61        7.93        6.07     2S         2S Metal PCL
# 15           0.78        0.66        0.59     2S         2S Metal PCL
# 16           2.95        3.04        3.07     2S         2S Metal PCL
# 17           6.18        7.00        7.78     2S         2S Metal PCL
# 18        9115.71     8672.14         NaN     AJ        A J Plast PCL
# 19        5706.18     5076.32         NaN     AJ        A J Plast PCL
# 20        3409.53     3595.82         NaN     AJ        A J Plast PCL
# 21         399.44      399.44         NaN     AJ        A J Plast PCL
# 22        7922.87     7083.89         NaN     AJ        A J Plast PCL
# 23          17.98      236.17         NaN     AJ        A J Plast PCL
# 24           0.05        0.59         NaN     AJ        A J Plast PCL
# 25           1.15        3.80         NaN     AJ        A J Plast PCL
# 26           0.52        6.74         NaN     AJ        A J Plast PCL
# 27           0.23        3.33         NaN     AJ        A J Plast PCL
# 28     28/12/2018  30/12/2019  30/04/2020     AJ        A J Plast PCL
# 29           8.15        8.25        9.50     AJ        A J Plast PCL
# ...           ...         ...         ...    ...                  ...
# 12714         NaN        0.36         NaN    ZEN   Zen Corp Group PCL
# 12715         NaN        7.28         NaN    ZEN   Zen Corp Group PCL
# 12716         NaN       11.17         NaN    ZEN   Zen Corp Group PCL
# 12717         NaN        3.38         NaN    ZEN   Zen Corp Group PCL
# 12718         NaN  30/12/2019  30/04/2020    ZEN   Zen Corp Group PCL
# 12719         NaN       14.60        9.25    ZEN   Zen Corp Group PCL
# 12720         NaN     4380.00     2775.00    ZEN   Zen Corp Group PCL
# 12721         NaN  30/09/2019  31/12/2019    ZEN   Zen Corp Group PCL
# 12722         NaN       36.83       26.12    ZEN   Zen Corp Group PCL
# 12723         NaN        3.11        1.94    ZEN   Zen Corp Group PCL
# 12724         NaN        4.70        4.78    ZEN   Zen Corp Group PCL
# 12725         NaN         NaN        4.86    ZEN   Zen Corp Group PCL
# 12726     1195.34     1158.63         NaN   ZIGA  Ziga Innovation PCL
# 12727      438.13      405.82         NaN   ZIGA  Ziga Innovation PCL
# 12728      757.21      752.81         NaN   ZIGA  Ziga Innovation PCL
# 12729      260.00      260.00         NaN   ZIGA  Ziga Innovation PCL
# 12730      871.02      795.30         NaN   ZIGA  Ziga Innovation PCL
# 12731       42.56       35.26         NaN   ZIGA  Ziga Innovation PCL
# 12732        0.08        0.07         NaN   ZIGA  Ziga Innovation PCL
# 12733        4.77        4.66         NaN   ZIGA  Ziga Innovation PCL
# 12734        5.53        4.67         NaN   ZIGA  Ziga Innovation PCL
# 12735        4.89        4.43         NaN   ZIGA  Ziga Innovation PCL
# 12736  28/12/2018  30/12/2019  30/04/2020   ZIGA  Ziga Innovation PCL
# 12737        1.76        1.02        1.15   ZIGA  Ziga Innovation PCL
# 12738      915.20      530.40      598.00   ZIGA  Ziga Innovation PCL
# 12739  30/09/2018  30/09/2019  31/12/2019   ZIGA  Ziga Innovation PCL
# 12740       18.65       14.32       16.67   ZIGA  Ziga Innovation PCL
# 12741        1.22        0.71        0.78   ZIGA  Ziga Innovation PCL
# 12742        1.45        1.44        1.45   ZIGA  Ziga Innovation PCL
# 12743        7.39        7.84        3.45   ZIGA  Ziga Innovation PCL
#
#             Stock Sector           Industry Name  Market Cap (m)  \
# 0        Basic Materials                   Steel         899.998
# 1        Basic Materials                   Steel         899.998
# 2        Basic Materials                   Steel         899.998
# 3        Basic Materials                   Steel         899.998
# 4        Basic Materials                   Steel         899.998
# 5        Basic Materials                   Steel         899.998
# 6        Basic Materials                   Steel         899.998
# 7        Basic Materials                   Steel         899.998
# 8        Basic Materials                   Steel         899.998
# 9        Basic Materials                   Steel         899.998
# 10       Basic Materials                   Steel         899.998
# 11       Basic Materials                   Steel         899.998
# 12       Basic Materials                   Steel         899.998
# 13       Basic Materials                   Steel         899.998
# 14       Basic Materials                   Steel         899.998
# 15       Basic Materials                   Steel         899.998
# 16       Basic Materials                   Steel         899.998
# 17       Basic Materials                   Steel         899.998
# 18     Consumer Cyclical  Packaging & Containers        3295.374
# 19     Consumer Cyclical  Packaging & Containers        3295.374
# 20     Consumer Cyclical  Packaging & Containers        3295.374
# 21     Consumer Cyclical  Packaging & Containers        3295.374
# 22     Consumer Cyclical  Packaging & Containers        3295.374
# 23     Consumer Cyclical  Packaging & Containers        3295.374
# 24     Consumer Cyclical  Packaging & Containers        3295.374
# 25     Consumer Cyclical  Packaging & Containers        3295.374
# 26     Consumer Cyclical  Packaging & Containers        3295.374
# 27     Consumer Cyclical  Packaging & Containers        3295.374
# 28     Consumer Cyclical  Packaging & Containers        3295.374
# 29     Consumer Cyclical  Packaging & Containers        3295.374
# ...                  ...                     ...             ...
# 12714  Consumer Cyclical             Restaurants        4170.000
# 12715  Consumer Cyclical             Restaurants        4170.000
# 12716  Consumer Cyclical             Restaurants        4170.000
# 12717  Consumer Cyclical             Restaurants        4170.000
# 12718  Consumer Cyclical             Restaurants        4170.000
# 12719  Consumer Cyclical             Restaurants        4170.000
# 12720  Consumer Cyclical             Restaurants        4170.000
# 12721  Consumer Cyclical             Restaurants        4170.000
# 12722  Consumer Cyclical             Restaurants        4170.000
# 12723  Consumer Cyclical             Restaurants        4170.000
# 12724  Consumer Cyclical             Restaurants        4170.000
# 12725  Consumer Cyclical             Restaurants        4170.000
# 12726    Basic Materials                   Steel         535.600
# 12727    Basic Materials                   Steel         535.600
# 12728    Basic Materials                   Steel         535.600
# 12729    Basic Materials                   Steel         535.600
# 12730    Basic Materials                   Steel         535.600
# 12731    Basic Materials                   Steel         535.600
# 12732    Basic Materials                   Steel         535.600
# 12733    Basic Materials                   Steel         535.600
# 12734    Basic Materials                   Steel         535.600
# 12735    Basic Materials                   Steel         535.600
# 12736    Basic Materials                   Steel         535.600
# 12737    Basic Materials                   Steel         535.600
# 12738    Basic Materials                   Steel         535.600
# 12739    Basic Materials                   Steel         535.600
# 12740    Basic Materials                   Steel         535.600
# 12741    Basic Materials                   Steel         535.600
# 12742    Basic Materials                   Steel         535.600
# 12743    Basic Materials                   Steel         535.600
#
#       Dividend Yield (%) Last (Close) Unnamed: 7
# 0                      7            2        THB
# 1                      7            2        THB
# 2                      7            2        THB
# 3                      7            2        THB
# 4                      7            2        THB
# 5                      7            2        THB
# 6                      7            2        THB
# 7                      7            2        THB
# 8                      7            2        THB
# 9                      7            2        THB
# 10                     7            2        THB
# 11                     7            2        THB
# 12                     7            2        THB
# 13                     7            2        THB
# 14                     7            2        THB
# 15                     7            2        THB
# 16                     7            2        THB
# 17                     7            2        THB
# 18                  1.21         8.25        THB
# 19                  1.21         8.25        THB
# 20                  1.21         8.25        THB
# 21                  1.21         8.25        THB
# 22                  1.21         8.25        THB
# 23                  1.21         8.25        THB
# 24                  1.21         8.25        THB
# 25                  1.21         8.25        THB
# 26                  1.21         8.25        THB
# 27                  1.21         8.25        THB
# 28                  1.21         8.25        THB
# 29                  1.21         8.25        THB
# ...                  ...          ...        ...
# 12714                  -         13.9        THB
# 12715                  -         13.9        THB
# 12716                  -         13.9        THB
# 12717                  -         13.9        THB
# 12718                  -         13.9        THB
# 12719                  -         13.9        THB
# 12720                  -         13.9        THB
# 12721                  -         13.9        THB
# 12722                  -         13.9        THB
# 12723                  -         13.9        THB
# 12724                  -         13.9        THB
# 12725                  -         13.9        THB
# 12726               7.77         1.03        THB
# 12727               7.77         1.03        THB
# 12728               7.77         1.03        THB
# 12729               7.77         1.03        THB
# 12730               7.77         1.03        THB
# 12731               7.77         1.03        THB
# 12732               7.77         1.03        THB
# 12733               7.77         1.03        THB
# 12734               7.77         1.03        THB
# 12735               7.77         1.03        THB
# 12736               7.77         1.03        THB
# 12737               7.77         1.03        THB
# 12738               7.77         1.03        THB
# 12739               7.77         1.03        THB
# 12740               7.77         1.03        THB
# 12741               7.77         1.03        THB
# 12742               7.77         1.03        THB
# 12743               7.77         1.03        THB
#
# [12744 rows x 15 columns]

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 29 13:46:19 2019

@author: YIT
"""

# -*- coding: utf-8 -*-
"""
Created on Sat Dec 28 15:34:58 2019

@author: Santi
"""


import pandas as pd
#import pickle

#### load data ####
dir_name = "C:\\Users\\YIT\\Python Stock Analysis\\"
stock_sector= pd.read_excel(dir_name + 'Stock Sector.xlsx')
stock_sector = stock_sector.loc[stock_sector['Symbol'].notnull(), :]
# remove REIT companies
stock_sector = stock_sector.loc[stock_sector['Industry Name'].str.startswith('REIT') == False, :]

## delete stocks that contain '-'
#stock_sector = stock_sector[stock_sector['Symbol'].str.contains('-') == False]

colname = stock_sector.columns
stock_sector.columns = [ 'Dividend Yield(%)' if x== 'Dividend Yield' else x  for x in colname]

stock_sector['Market Cap (m)'] = pd.to_numeric(stock_sector['Market Cap (m)'], errors='coerce')

sector = stock_sector.groupby('Stock Sector').agg({'Market Cap (m)':'sum'})
industry = stock_sector.groupby('Industry Name').agg({'Market Cap (m)':'count'})


stock_name = []
pe_list = []
stock_data_list = []
column_max_len = []
max_len_column_names = 0
for i in range(stock_sector.shape[0]):
    stock = str(stock_sector.iloc[i,0]).upper()
    ch_url = 'https://www.set.or.th/set/companyhighlight.do?symbol=' + stock +'&language=en&country=US'
    try:
        company_highlights = pd.read_html(ch_url)[0]
    except ValueError:
        company_highlights = pd.DataFrame()
        pass
    if company_highlights.empty == False:
        stock_name.append(stock)
        column_names = [dat for  i, dat in company_highlights.columns]
        max_len_column_names = len(column_names) if len(column_names) > max_len_column_names else max_len_column_names
        column_max_len = column_names if len(column_names) >= max_len_column_names else column_max_len
        company_highlights.columns = column_names
        company_highlights = company_highlights.loc[(company_highlights['Statistics as of']!='Financial Data') & (company_highlights['Statistics as of']!='Financial Ratio')]
        company_highlights['Symbol'] = stock
        stock_data_list.append(company_highlights)
        print(stock +' '+ str(round( ((i+1)/(stock_sector.shape[0]))*100, 2)) +'%')



# append all the dataframes
finance_info = pd.concat(stock_data_list,sort=False)   
statistics_name = finance_info['Statistics as of'].unique()

# clean environment
if 'stock_data_list' in locals().keys():
    del stock_data_list
#########

finance_info2 = pd.merge(finance_info, stock_sector, on = 'Symbol', how='left')

#stock_sector.groupby('Symbol').agg({'Symbol':'count'})
finance_info2.to_csv(dir_name + 'finance info.csv')

finance_info2.loc[finance_info2['Statistics as of']=='P/E',:].groupby('Industry Name').agg({'21/12/2019':'sum'})
#### save to disk
'''
with open('C:\\Users\YIT\Python Stock Analysis\stock_data_list.pickle', 'wb') as f:
    pickle.dump(stock_data_list, f)
with open('C:\\Users\YIT\Python Stock Analysis\stock_name.pickle', 'wb') as f:
    pickle.dump(stock_name, f)


with open('C:\\Users\YIT\Python Stock Analysis\stock_data_list.pickle', 'rb') as f:
    stock_data_list = pickle.load(f)
with open('C:\\Users\YIT\Python Stock Analysis\stock_name.pickle', 'rb') as f:
    stock_name = pickle.load(f)
'''

#########

#pe_list.append(company_highlights.loc[company_highlights['Statistics as of']=='P/E',company_highlights.columns[-1]])

### prepare dataframe for retrieving financial info.
# Out:
# 2S 0.14%
# AJ 0.28%
# AH 0.41%
# ABICO 0.55%
# ACC 0.69%
# ADVANC 0.83%
# AIT 0.96%
# AEC 1.1%
# AEONTS 1.24%
# AU 1.38%
# APURE 1.51%
# AIE 1.65%
# AHC 1.79%
# AIRA 1.93%
# AF 2.06%
# AOT 2.2%
# AJA 2.34%
# AKP 2.48%
# ALL 2.61%
# ALLA 2.75%
# AYUD 2.89%
# ALT 3.03%
# ALUCON 3.16%
# AMA 3.3%
# AMANAH 3.44%
# AMARIN 3.58%
# AMATA 3.71%
# AMATAV 3.85%
# ANAN 3.99%
# AP 4.13%
# APEX 4.26%
# APP 4.4%
# ADB 4.54%
# AQ 4.68%
# AQUA 4.81%
# A 4.95%
# ARIN 5.09%
# ARIP 5.23%
# ARROW 5.36%
# AAV 5.64%
# ABM 5.78%
# ACAP 5.91%
# AFC 6.05%
# AGE 6.19%
# ASIA 6.33%
# AMC 6.46%
# ASP 6.6%
# APCS 6.74%
# ASK 6.88%
# AI 7.02%
# ASIMAR 7.15%
# APCO 7.29%
# ASIAN 7.43%
# AS 7.57%
# ASN 7.7%
# A5 7.84%
# AWC 7.98%
# ATP30 8.12%
# ACG 8.25%
# BGRIM 8.39%
# B52 8.53%
# BROCK 8.67%
# BCP 8.8%
# BA 8.94%
# BAFS 9.08%
# BBL 9.22%
# BCH 9.35%
# BAM 9.49%
# BKD 9.63%
# BDMS 9.77%
# BEM 9.9%
# BKI 10.04%
# BLAND 10.18%
# BLA 10.32%
# POST 10.45%
# BR 10.59%
# BM 10.73%
# BUI 10.87%
# BSBM 11.0%
# BAY 11.14%
# BANPU 11.28%
# BPP 11.42%
# BCPG 11.55%
# BEAUTY 11.69%
# BEC 11.83%
# B 11.97%
# BJC 12.1%
# BWG 12.24%
# BGC 12.38%
# BGT 12.52%
# BIG 12.65%
# BCT 12.79%
# BJCHI 12.93%
# BLISS 13.07%
# BC 13.2%
# BTNC 13.34%
# BTW 13.48%
# BTS 13.62%
# BSM 13.76%
# BH 13.89%
# BRR 14.03%
# BIZ 14.17%
# BOL 14.31%
# CIG 14.44%
# CCET 14.58%
# CEN 14.72%
# CBG 14.99%
# CPH 15.13%
# CAZ 15.27%
# CPN 15.41%
# CENTEL 15.54%
# CK 15.68%
# CWT 15.82%
# CMC 15.96%
# CHARAN 16.09%
# CI 16.23%
# CPF 16.37%
# CTW 16.51%
# CHAYO 16.64%
# CMAN 16.78%
# CHEWA 16.92%
# CMR 17.06%
# CM 17.19%
# CRD 17.33%
# CHO 17.47%
# CCP 17.61%
# CHOW 17.74%
# CNT 17.88%
# CRANE 18.02%
# CHG 18.16%
# CPI 18.29%
# CHUO 18.43%
# CIMBT 18.57%
# CSR 18.71%
# CITY 18.84%
# CKP 18.98%
# CMO 19.12%
# COL 19.26%
# COMAN 19.53%
# CSS 19.67%
# CPW 19.81%
# CGD 19.94%
# CGH 20.08%
# CPALL 20.22%
# CPL 20.36%
# CPR 20.5%
# CPT 20.63%
# CSC 20.77%
# CSP 20.91%
# DTCI 21.05%
# DCON 21.18%
# DELTA 21.32%
# DEMCO 21.46%
# DCORP 21.6%
# D 21.73%
# TIP 21.87%
# DRT 22.01%
# DIMET 22.15%
# DDD 22.28%
# DOD 22.42%
# DOHOME 22.56%
# DTC 22.7%
# DCC 22.83%
# EFORL 22.97%
# EASON 23.11%
# ECF 23.25%
# ECL 23.38%
# EPG 23.52%
# ESTAR 23.8%
# ETE 23.93%
# EASTW 24.07%
# EKH 24.21%
# AKR 24.35%
# EGCO 24.48%
# EIC 24.62%
# EMC 24.76%
# EA 24.9%
# ESSO 25.03%
# EE 25.17%
# UREKA 25.31%
# EVER 25.45%
# XO 25.58%
# FANCY 25.72%
# FE 25.86%
# FVC 26.0%
# FNS 26.13%
# FSS 26.27%
# FTE 26.41%
# FLOYD 26.55%
# FN 26.69%
# FORTH 26.96%
# FSMART 27.1%
# FPI 27.24%
# FPT 27.37%
# FMT 27.51%
# GCAP 27.65%
# GJS 27.79%
# GSTEEL 28.06%
# GEL 28.2%
# GENCO 28.34%
# GTB 28.47%
# GFPT 28.61%
# GC 28.75%
# GLOCON 28.89%
# GGC 29.02%
# GPSC 29.16%
# GSC 29.3%
# GSC-F 29.57%
# GBX 29.71%
# GRAMMY 29.85%
# GOLD 29.99%
# SUTHA 30.12%
# GYT 30.26%
# GLAND 30.4%
# GPI 30.54%
# GRAND 30.67%
# GIFT 30.81%
# GREEN 30.95%
# GL 31.09%
# GULF 31.22%
# GUNKUL 31.36%
# HTC 31.5%
# HTECH 31.64%
# HANA 31.77%
# HARN 31.91%
# BAT-3K 32.05%
# HPT 32.19%
# HMPRO 32.32%
# HUMAN 32.46%
# HFT 32.6%
# HYDRO 32.74%
# ICC 32.87%
# ICHI 33.01%
# IFS 33.15%
# INSURE 33.29%
# ILM 33.43%
# IVL 33.56%
# ICN 33.7%
# INSET 33.84%
# INGRS 33.98%
# IRC 34.11%
# IFEC 34.25%
# IP 34.39%
# IHL 34.53%
# ILINK 34.66%
# IMH 34.94%
# IRCP 35.08%
# INET 35.21%
# INTUCH 35.35%
# IRPC 35.49%
# IT 35.63%
# ITD 35.76%
# JSP 35.9%
# JCT 36.04%
# J 36.18%
# JAS 36.31%
# JTS 36.45%
# JMART 36.59%
# JCKH 36.73%
# JCK 36.86%
# JKN 37.0%
# JMT 37.14%
# JUBILE 37.28%
# JUTHA 37.41%
# JWD 37.55%
# KC 37.83%
# KWM 37.96%
# KYE 38.1%
# KAMART 38.24%
# KTIS 38.38%
# KBANK 38.51%
# KCE 38.65%
# KGI 38.79%
# KSL 38.93%
# KBS 39.06%
# CHOTI 39.2%
# KKP 39.34%
# KIAT 39.48%
# KWG 39.61%
# K 39.75%
# KTB 39.89%
# KWC 40.03%
# KCAR 40.17%
# KTC 40.3%
# KTECH 40.44%
# POMPUI 40.58%
# KKC 40.72%
# KUMWEL 40.85%
# LPN 40.99%
# LPH 41.13%
# LRH 41.27%
# LALIN 41.4%
# LST 41.54%
# LH 41.68%
# LANNA 41.82%
# LDC 41.95%
# LIT 42.09%
# LEE 42.23%
# LHFG 42.37%
# LHK 42.64%
# LOXLEY 42.78%
# MPIC 42.92%
# MVP 43.05%
# MCS 43.19%
# MK 43.33%
# M-CHAI 43.47%
# MAJOR 43.6%
# MJD 43.74%
# MALEE 43.88%
# MANRIN 44.02%
# MACO 44.15%
# MATCH 44.43%
# MATI 44.57%
# MAX 44.7%
# MBKET 44.84%
# MBK 44.98%
# MC 45.12%
# MCOT 45.25%
# MDX 45.39%
# MEGA 45.53%
# MGT 45.67%
# META 45.8%
# MSC 45.94%
# MFC 46.08%
# MGE 46.22%
# MFEC 46.35%
# MIDA 46.49%
# ML 46.63%
# MILL 46.77%
# MINT 46.91%
# MITSIB 47.04%
# M 47.18%
# MODERN 47.32%
# MONO 47.46%
# MOONG 47.59%
# MORE 47.73%
# MPG 47.87%
# MTI 48.01%
# MTC 48.14%
# MM 48.28%
# MBAX 48.42%
# METCO 48.56%
# NCH 48.69%
# NDR 48.83%
# NSI 48.97%
# NYT 49.11%
# NBC 49.24%
# NINE 49.38%
# NMG 49.52%
# NNCL 49.66%
# NKI 49.79%
# NWR 49.93%
# NCL 50.07%
# NEP 50.21%
# NETBAY 50.34%
# NPK 50.48%
# NC 50.62%
# NEWS 50.76%
# NEX 50.89%
# NFC 51.03%
# NVD 51.17%
# NOBLE 51.31%
# NOK 51.44%
# NTV 51.58%
# NER 51.72%
# NUSA 51.86%
# OCC 51.99%
# OCEAN 52.13%
# OGC 52.27%
# OHTL 52.41%
# OISHI 52.54%
# OTO-F 52.68%
# OSP 52.96%
# PCSGH 53.09%
# PACE 53.23%
# PAP 53.37%
# PDI 53.51%
# PAE 53.65%
# PAF 53.78%
# PJW 53.92%
# PK 54.06%
# PATO 54.2%
# PRG 54.33%
# PG 54.47%
# PERM 54.61%
# PL 54.75%
# PHOL 54.88%
# PICO 55.02%
# PIMO 55.16%
# PLANB 55.3%
# PLANET 55.43%
# PMTA 55.57%
# POLAR 55.71%
# PTL 55.85%
# PPM 55.98%
# INOX 56.12%
# PLE 56.26%
# PSTC 56.4%
# PPPM 56.53%
# PRAKIT 56.67%
# PDJ 56.81%
# PR9 56.95%
# PREB 57.08%
# PSL 57.22%
# PRECHA 57.36%
# PE 57.5%
# PM 57.63%
# PPP 57.77%
# PT 57.91%
# PB 58.05%
# PRM 58.18%
# PRIME 58.32%
# PRINC 58.46%
# PRIN 58.6%
# PDG 58.73%
# PRO 58.87%
# PPS 59.01%
# PF 59.15%
# PROUD 59.28%
# PSH 59.42%
# PTG 59.56%
# PTTEP 59.7%
# PTTGC 59.83%
# PTT 59.97%
# PYLON 60.11%
# QTC 60.25%
# QLT 60.39%
# Q-CON 60.52%
# QH 60.66%
# RBF 60.8%
# RML 60.94%
# RP 61.07%
# RJH 61.21%
# RAM 61.35%
# RATCH 61.49%
# RPH 61.62%
# THANI 61.76%
# RWI 61.9%
# RCL 62.04%
# TITLE 62.17%
# RICH 62.31%
# RSP 62.45%
# RICHY 62.59%
# ROCK 62.86%
# ROJNA 63.0%
# RCI 63.14%
# ROH 63.27%
# RPC 63.41%
# RS 63.55%
# S&J 63.69%
# SNP 63.82%
# S11 63.96%
# SORKON 64.1%
# SPVI 64.24%
# SPACK 64.37%
# SKN 64.51%
# SAAM 64.65%
# SABINA 64.79%
# SAFARI 64.92%
# SPI 65.06%
# SPC 65.2%
# SCG 65.34%
# SMIT 65.61%
# SMPC 65.75%
# PORT 65.89%
# SUC 66.02%
# SSI 66.16%
# SKE 66.3%
# COLOR 66.44%
# SALEE 66.57%
# SLP 66.71%
# SAMART 66.85%
# SDC 66.99%
# SAMTEL 67.13%
# SAM 67.26%
# SVH 67.4%
# SAMCO 67.54%
# SANKO 67.68%
# SIRI 67.81%
# SAPPE 67.95%
# SAWANG 68.09%
# SC 68.23%
# SCN 68.36%
# COTTO 68.5%
# SCI 68.64%
# SEAOIL 68.78%
# SEAFCO 68.91%
# CFRESH 69.05%
# ZMICO 69.19%
# SE-ED 69.33%
# SELIC 69.46%
# SENA 69.6%
# SSP 69.74%
# SSC 69.88%
# 7UP 70.01%
# SGF 70.15%
# SHANG 70.29%
# SWC 70.43%
# STHAI 70.56%
# SCC 70.7%
# SCCC 70.84%
# SE 70.98%
# SFP 71.11%
# SF 71.25%
# GLOBAL 71.39%
# MAKRO 71.53%
# SPG 71.66%
# SIAM 71.94%
# SSSC 72.08%
# SPA 72.21%
# SGP 72.35%
# SR 72.49%
# SKR 72.63%
# SIMAT 72.76%
# SINGER 72.9%
# S 73.04%
# STEC 73.18%
# SIS 73.31%
# SISB 73.45%
# SKY 73.59%
# SMART 73.73%
# SNC 73.87%
# SOLAR 74.0%
# SAT 74.14%
# SONIC 74.28%
# SCP 74.42%
# SPCG 74.55%
# STA 74.69%
# SRICHA 74.83%
# SAWAD 74.97%
# BFIT 75.1%
# SITHAI 75.24%
# VIH 75.38%
# SPRC 75.52%
# STAR 75.65%
# SFLEX 75.79%
# STARK 75.93%
# SMT 76.07%
# STC 76.2%
# STI 76.34%
# STPI 76.48%
# SST 76.62%
# SUN 76.75%
# SPALI 76.89%
# SUPER 77.03%
# SSF 77.17%
# SUSCO 77.3%
# SVI 77.44%
# SVOA 77.58%
# SYMC 77.72%
# SMK 77.85%
# ASAP 77.99%
# SYNEX 78.13%
# SYNTEC 78.27%
# T 78.4%
# TKS 78.54%
# TMC 78.68%
# TMILL 78.82%
# TACC 78.95%
# TCJ 79.09%
# TKT 79.23%
# TKN 79.5%
# TAPAC 79.64%
# TSTH 79.78%
# TBSP 79.92%
# TCMC 80.06%
# TEAMG 80.19%
# TEAM 80.33%
# TM 80.47%
# TMI 80.61%
# TPCORP 80.74%
# TAE 80.88%
# THAI 81.02%
# TCC 81.16%
# TCCC 81.29%
# TCOAT 81.43%
# TIGER 81.57%
# TFI 81.71%
# TFG 81.84%
# SEG 81.98%
# KASET 82.12%
# TMD 82.26%
# TMW 82.39%
# THMUI 82.53%
# TNH 82.67%
# TNPC 82.81%
# TNR 82.94%
# TNDT 83.08%
# TOPP 83.22%
# TOP 83.36%
# TOG 83.49%
# TPP 83.63%
# TPAC 83.77%
# TPLAS 83.91%
# TPA 84.04%
# TPOLY 84.18%
# TFMAMA 84.32%
# TR 84.46%
# THRE 84.59%
# TRUBB 84.73%
# TRU 84.87%
# STANLY 85.14%
# TSC 85.28%
# TSTE 85.42%
# TTI 85.56%
# TU 85.69%
# TVO 85.83%
# WACOAL 85.97%
# TWPC 86.11%
# TWP 86.24%
# THCOM 86.38%
# TGPRO 86.52%
# TIW 86.66%
# THREL 86.8%
# SAUCE 86.93%
# TVI 87.07%
# TCAP 87.21%
# TNP 87.35%
# THANA 87.48%
# THIP 87.62%
# TNL 87.76%
# BROOK 87.9%
# ERW 88.03%
# PLAT 88.17%
# TPS 88.31%
# SCB 88.45%
# THE 88.58%
# TSI 88.72%
# TSR 88.86%
# TK 89.0%
# THG 89.13%
# KDH 89.27%
# TTA 89.41%
# TSF 89.55%
# TASCO 89.68%
# TIPCO 89.82%
# TRT 89.96%
# TISCO 90.1%
# TMB 90.23%
# TMT 90.37%
# TOA 90.51%
# TH 90.65%
# THL 90.78%
# TTT 90.92%
# DTAC 91.06%
# TPIPL 91.47%
# TPIPP 91.61%
# TQM 91.75%
# TRC 91.88%
# TNITY 92.02%
# III 92.16%
# TRITN 92.3%
# TC 92.43%
# TRUE 92.57%
# TTCL 92.71%
# TTW 92.85%
# TVD 92.98%
# TVT 93.12%
# TWZ 93.26%
# TYCN 93.4%
# U 93.54%
# UWC 93.67%
# UAC 93.81%
# UBIS 93.95%
# UEC 94.09%
# AUCT 94.22%
# UMI 94.36%
# UKEM 94.5%
# UPF 94.64%
# UP 94.77%
# UT 94.91%
# UNIQ 95.05%
# UMS 95.19%
# UPOIC 95.32%
# UTP 95.46%
# UPA 95.6%
# UVAN 95.74%
# UV 95.87%
# UOBKH 96.01%
# VL 96.15%
# VNG 96.29%
# VARO 96.42%
# VI 96.56%
# VRANDA 96.7%
# VGI 96.84%
# VIBHA 96.97%
# VPO 97.11%
# KUN 97.25%
# VCOM 97.39%
# VNT 97.52%
# NEW 97.66%
# WPH 97.8%
# WAVE 97.94%
# WR 98.07%
# WHA 98.21%
# WHAUP 98.35%
# WG 98.49%
# WICE 98.62%
# WIIK 98.76%
# WINNER 98.9%
# WORK 99.04%
# WORLD 99.17%
# WP 99.31%
# WIN 99.45%
# YCI 99.59%
# YUASA 99.72%
# ZEN 99.86%
# ZIGA 100.0%
# C:\Users\YIT\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1315: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '21/12/2019'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ee2a5d2860f9> in <module>
#      76 finance_info2.to_csv(dir_name + 'finance info.csv')
#      77
# ---> 78 finance_info2.loc[finance_info2['Statistics as of']=='P/E',:].groupby('Industry Name').agg({'21/12/2019':'sum'})
#      79 #### save to disk
#      80 '''
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     496
#     497                 try:
# --> 498                     result = _agg(arg, _agg_1dim)
#     499                 except SpecificationError:
#     500
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     447                 result = compat.OrderedDict()
#     448                 for fname, agg_how in compat.iteritems(arg):
# --> 449                     result[fname] = func(fname, agg_how)
#     450                 return result
#     451
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     426                 aggregate a 1-dim with how
#     427                 """
# --> 428                 colg = self._gotitem(name, ndim=1, subset=subset)
#     429                 if colg.ndim != 1:
#     430                     raise SpecificationError("nested dictionary is ambiguous "
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _gotitem(self, key, ndim, subset)
#    1341         elif ndim == 1:
#    1342             if subset is None:
# -> 1343                 subset = self.obj[key]
#    1344             return SeriesGroupBy(subset, selection=key,
#    1345                                  grouper=self.grouper)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '21/12/2019'
